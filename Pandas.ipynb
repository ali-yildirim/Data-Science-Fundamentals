# %%
import pandas as pd

# %%
#2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors = pd.Series(["Blue", "Red", "White"])

# %%
# data frame = 2 dimensional
car_data = pd.DataFrame({"car make": series, "color": colors})

# %%
car_data
# Out:
#   car make  color
# 0      BMW   Blue
# 1   Toyota    Red
# 2    Honda  White

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales.head(1)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[1]
# Out:
# Make                 Honda
# Colour                 Red
# Odometer (KM)        87899
# Doors                    4
# Price            $5,000.00
# Name: 1, dtype: object

# %%
# .iloc => position, .loc => index

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.loc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"] == 4)
# Out:
# Doors   False  True
# Make
# BMW         1     0
# Honda       0     3
# Nissan      0     2
# Toyota      1     3

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.hist("Odometer (KM)")
# Out:
# array([[<AxesSubplot:title={'center':'Odometer (KM)'}>]], dtype=object)

# %%
dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)
#
# NameError: name 'dataframe' is not defined

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\Casper\AppData\Local\Temp\ipykernel_23492\2312081839.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"] / 100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %% [markdown]
# #Column from Series

# %%
seats_column = pd.Series([2, 3, 4, 5, 6])

# %%
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    2.0
# 1   honda    Red          87899      4   5000.0    3.0
# 2  toyota   Blue          32549      3   7000.0    4.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    6.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    2.0
# 1   honda    Red          87899      4   5000.0    3.0
# 2  toyota   Blue          32549      3   7000.0    4.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    6.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %% [markdown]
# #Column from Python List

# %%
fuel_economy = [7.5, 9.2, 5, 4.3, 5, 6, 7, 4, 3, 4.8]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    2.0             7.5
# 1   honda    Red          87899      4   5000.0    3.0             9.2
# 2  toyota   Blue          32549      3   7000.0    4.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             4.3
# 4  nissan  White         213095      4   3500.0    6.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             7.0
# 7   honda   Blue          54738      4   7000.0    5.0             4.0
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.8

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    2.0             7.5
# 1   honda    Red          87899      4   5000.0    3.0             9.2
# 2  toyota   Blue          32549      3   7000.0    4.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             4.3
# 4  nissan  White         213095      4   3500.0    6.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             7.0
# 7   honda   Blue          54738      4   7000.0    5.0             4.0
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.8
#
#    Total Fuel Used  Total Fuel Used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# 2         1627.450             1627.450
# 3          480.697              480.697
# 4        10654.750            10654.750
# 5         5952.780             5952.780
# 6         3198.860             3198.860
# 7         2189.520             2189.520
# 8         1800.000             1800.000
# 9         1516.800             1516.800

# %% [markdown]
# #Create a column from a single value

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    2.0             7.5
# 1   honda    Red          87899      4   5000.0    3.0             9.2
# 2  toyota   Blue          32549      3   7000.0    4.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             4.3
# 4  nissan  White         213095      4   3500.0    6.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             7.0
# 7   honda   Blue          54738      4   7000.0    5.0             4.0
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.8
#
#    Total Fuel Used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# 3              480.697                 4
# 4            10654.750                 4
# 5             5952.780                 4
# 6             3198.860                 4
# 7             2189.520                 4
# 8             1800.000                 4
# 9             1516.800                 4

# %%
car_sales = car_sales.drop("Total Fuel Used", axis = 1)
car_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 car_sales = car_sales.drop("Total Fuel Used", axis = 1)
#       2 car_sales
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Total Fuel Used'] not found in axis"

# %%
car_sales.sample(frac = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   7000.0    4.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             7.0
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 9  nissan  White          31600      4   9700.0    5.0             4.8
# 7   honda   Blue          54738      4   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             4.3
# 0  toyota  White         150043      4   4000.0    2.0             7.5
# 4  nissan  White         213095      4   3500.0    6.0             5.0
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 1   honda    Red          87899      4   5000.0    3.0             9.2
#
#    Total Fuel Used (L)  Number of wheels
# 2             1627.450                 4
# 6             3198.860                 4
# 5             5952.780                 4
# 9             1516.800                 4
# 7             2189.520                 4
# 3              480.697                 4
# 0            11253.225                 4
# 4            10654.750                 4
# 8             1800.000                 4
# 1             8086.708                 4

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled.reset_index(inplace = True, drop = True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     bmw  Black          11179      5  22000.0    5.0             4.3
# 1   honda    Red          87899      4   5000.0    3.0             9.2
# 2  nissan  White          31600      4   9700.0    5.0             4.8
# 3   honda   Blue          54738      4   7000.0    5.0             4.0
# 4  toyota  White         150043      4   4000.0    2.0             7.5
# 5  toyota  White          60000      4   6250.0    5.0             3.0
# 6   honda   Blue          45698      4   7500.0    5.0             7.0
# 7  toyota  Green          99213      4   4500.0    5.0             6.0
# 8  nissan  White         213095      4   3500.0    6.0             5.0
# 9  toyota   Blue          32549      3   7000.0    4.0             5.0
#
#    Total Fuel Used (L)  Number of wheels
# 0              480.697                 4
# 1             8086.708                 4
# 2             1516.800                 4
# 3             2189.520                 4
# 4            11253.225                 4
# 5             1800.000                 4
# 6             3198.860                 4
# 7             5952.780                 4
# 8            10654.750                 4
# 9             1627.450                 4

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White   36631.591797      4   4000.0    2.0             7.5
# 1   honda    Red   21459.716797      4   5000.0    3.0             9.2
# 2  toyota   Blue    7946.533203      3   7000.0    4.0             5.0
# 3     bmw  Black    2729.248047      5  22000.0    5.0             4.3
# 4  nissan  White   52025.146484      4   3500.0    6.0             5.0
# 5  toyota  Green   24221.923828      4   4500.0    5.0             6.0
# 6   honda   Blue   11156.738281      4   7500.0    5.0             7.0
# 7   honda   Blue   13363.769531      4   7000.0    5.0             4.0
# 8  toyota  White   14648.437500      4   6250.0    5.0             3.0
# 9  nissan  White    7714.843750      4   9700.0    5.0             4.8
#
#    Total Fuel Used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# 3              480.697                 4
# 4            10654.750                 4
# 5             5952.780                 4
# 6             3198.860                 4
# 7             2189.520                 4
# 8             1800.000                 4
# 9             1516.800                 4
